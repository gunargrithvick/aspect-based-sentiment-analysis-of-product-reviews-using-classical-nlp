# %% [markdown]
# # Standalone ABSA System Analysis
#
# This notebook summarizes the implemented classical NLP system. It does not train an LLM or generate text.

# %%
from pathlib import Path
import json
import pandas as pd

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'data').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
print(PROJECT_ROOT)

# %% [markdown]
# ## Dataset summary

# %%
dataset_summary = json.loads((PROJECT_ROOT / 'outputs' / 'dataset_summary.json').read_text())
pd.Series(dataset_summary, name='value')

# %%
polarity_counts = pd.read_csv(PROJECT_ROOT / 'reports' / 'tables' / 'polarity_distribution.csv')
polarity_counts

# %% [markdown]
# ## Model comparison

# %%
comparison = pd.read_csv(PROJECT_ROOT / 'reports' / 'tables' / 'final_model_comparison.csv')
comparison

# %% [markdown]
# ## Error categories

# %%
error_summary = json.loads((PROJECT_ROOT / 'outputs' / 'error_analysis_summary.json').read_text())
pd.Series(error_summary['error_counts'], name='count')

# %% [markdown]
# ## Standalone inference example

# %%
import sys
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
from classical_absa.inference_pipeline import AspectBasedSentimentAnalyzer

analyzer = AspectBasedSentimentAnalyzer.from_model_directory(PROJECT_ROOT / 'models')
analyzer.analyze('The battery life is terrible.')
